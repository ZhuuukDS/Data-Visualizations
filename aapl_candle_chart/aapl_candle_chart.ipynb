# %% [markdown]
# ## Candlestick Chart
# ____

# %% [markdown]
# A candlestick chart is a data visualization tool used to analyze the price movements of stocks, cryptocurrencies, currencies, and other financial instruments.

# %% [markdown]
# As this chart is mainly used to analyze the price movements of financial instruments, so I will be using the Apple stock price data for this task. Let's take data on Apple’s stock price for the past three months from Yahoo Finance.

# %%
import pandas as pd
import yfinance as yf #  API provided by Yahoo Finance to collect the latest stock price data
import datetime
from datetime import date, timedelta
import plotly.graph_objects as go

end_date = date.today() # today is the end day in our time series

start_date = date.today() - timedelta(days=90) # we'll start a time series starting 30 days ago

data = yf.download('AAPL', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)

data.index = data.index.strftime("%Y-%m-%d")
data['Date'] = data.index
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#          Open        High         Low       Close   Adj Close    Volume  \
# 0  145.759995  148.449997  145.050003  145.860001  145.657669  77588800
# 1  142.990005  146.449997  142.119995  145.490005  145.288193  71185600
# 2  144.080002  148.949997  143.250000  148.470001  148.264053  78140700
# 3  149.779999  150.860001  148.199997  150.169998  149.961700  76259900
# 4  150.740005  151.570007  146.699997  147.070007  146.865997  81420900
#
#          Date
# 0  2022-07-12
# 1  2022-07-13
# 2  2022-07-14
# 3  2022-07-15
# 4  2022-07-18

# %%
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"], 
                                        high=data["High"],
                                        low=data["Low"], 
                                        close=data["Close"])])
figure.update_layout(title = "Apple Stock Price Analysis", 
                     xaxis_rangeslider_visible=False)
#figure.write_image('candlechart.png')
figure.show('png')

# %% [markdown]
# ### Summary
# So this is how we can use the `plotly` library in Python for visualizing a candlestick chart.
